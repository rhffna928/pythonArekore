# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.그래프 기본

# %%
x = [1,2,3]
y = [2,4,8]
plt.plot(x, y)

# %%
print(plt.plot(x, y))
# Out:
# [<matplotlib.lines.Line2D object at 0x0000010A4EEAF910>]

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x,y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x,y)
plt.title('꺾은 선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은 선 그래프')
# c:\python38\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from current font.
#   func(*args, **kwargs)
# c:\python38\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   func(*args, **kwargs)
# c:\python38\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   func(*args, **kwargs)
# c:\python38\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   func(*args, **kwargs)
# c:\python38\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   func(*args, **kwargs)
# c:\python38\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   func(*args, **kwargs)
# c:\python38\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\python38\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\python38\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\python38\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\python38\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\python38\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['DejaVu Serif',
#  'DejaVu Sans Display',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Serif Display',
#  'STIXSizeFiveSym',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'STIXGeneral',
#  'cmmi10',
#  'DejaVu Serif',
#  'STIXSizeOneSym',
#  'cmex10',
#  'cmtt10',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'cmss10',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'STIXSizeTwoSym',
#  'cmr10',
#  'STIXSizeThreeSym',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'STIXSizeFourSym',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'cmb10',
#  'STIXGeneral',
#  'STIXGeneral',
#  'cmsy10',
#  'STIXNonUnicode',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'DejaVu Serif',
#  'Engravers MT',
#  'HCR Batang Ext',
#  'Gill Sans MT Condensed',
#  'Algerian',
#  'Dubai',
#  'Candara',
#  'Ink Free',
#  'Papyrus',
#  'Yu Gothic',
#  'Symbol',
#  'Nirmala UI',
#  'Malgun Gothic',
#  'Microsoft Tai Le',
#  'Tahoma',
#  'Baskerville Old Face',
#  'Rockwell Condensed',
#  'Californian FB',
#  'Segoe UI',
#  'Cambria',
#  'Comic Sans MS',
#  'Leelawadee UI',
#  'HYHeadLine-Medium',
#  'Bodoni MT',
#  'Century Schoolbook',
#  'Ravie',
#  'Modern No. 20',
#  'Times New Roman',
#  'Ami R',
#  'Consolas',
#  'HCR Dotum',
#  'Centaur',
#  'HyhwpEQ',
#  'Colonna MT',
#  'Bookman Old Style',
#  'Comic Sans MS',
#  'Sans Serif Collection',
#  'Franklin Gothic Medium',
#  'Gill Sans MT',
#  'Segoe UI',
#  'Bell MT',
#  'HCR Dotum',
#  'Consolas',
#  'Georgia',
#  'Bodoni MT',
#  'Bell MT',
#  'Vladimir Script',
#  'Ebrima',
#  'Calibri',
#  'Arial Rounded MT Bold',
#  'Calibri',
#  'Segoe Print',
#  'Leelawadee UI',
#  'Georgia',
#  'Tw Cen MT',
#  'Jokerman',
#  'Cambria',
#  'Wide Latin',
#  'Agency FB',
#  'Bodoni MT',
#  'Goudy Old Style',
#  'Pristina',
#  'HYShortSamul-Medium',
#  'Lucida Sans Typewriter',
#  'Franklin Gothic Demi',
#  'Hancom Gothic',
#  'Palace Script MT',
#  'Lucida Bright',
#  'Microsoft JhengHei',
#  'Tw Cen MT',
#  'Harlow Solid Italic',
#  'Imprint MT Shadow',
#  'Segoe UI',
#  'LG Smart UI',
#  'Trebuchet MS',
#  'Cooper Black',
#  'Bauhaus 93',
#  'Edwardian Script ITC',
#  'Sylfaen',
#  'Century Schoolbook',
#  'MS Reference Specialty',
#  'Calibri',
#  'Lucida Fax',
#  'HYSinMyeongJo-Medium',
#  'HYPost-Light',
#  'Goudy Old Style',
#  'Lucida Fax',
#  'Microsoft YaHei',
#  'Segoe UI',
#  'Corbel',
#  'Segoe UI Historic',
#  'Bodoni MT',
#  'Cambria',
#  'Microsoft JhengHei',
#  'Castellar',
#  'Lucida Console',
#  'Century Gothic',
#  'Hancom MalangMalang',
#  'Bookman Old Style',
#  'Leelawadee UI',
#  'New Gulim',
#  'Vivaldi',
#  'Javanese Text',
#  'Bodoni MT',
#  'Microsoft New Tai Lue',
#  'MS Reference Sans Serif',
#  'Hancom Gothic',
#  'Garamond',
#  'HancomEQN',
#  'Bookman Old Style',
#  'Old English Text MT',
#  'Lucida Sans Typewriter',
#  'Perpetua',
#  'MS Outlook',
#  'HCR Dotum Ext',
#  'Franklin Gothic Medium Cond',
#  'Haettenschweiler',
#  'NewJumja',
#  'Viner Hand ITC',
#  'Footlight MT Light',
#  'Freestyle Script',
#  'Magic R',
#  'Gill Sans Ultra Bold Condensed',
#  'Times New Roman',
#  'Impact',
#  'Franklin Gothic Heavy',
#  'HYGungSo-Bold',
#  'Constantia',
#  'Parchment',
#  'Tw Cen MT Condensed',
#  'Nirmala UI',
#  'Lucida Calligraphy',
#  'Chiller',
#  'Segoe Fluent Icons',
#  'Segoe UI',
#  'Perpetua Titling MT',
#  'Segoe UI Symbol',
#  'Garamond',
#  'Wingdings',
#  'Verdana',
#  'Calibri',
#  'Bodoni MT',
#  'Rockwell Extra Bold',
#  'Microsoft Sans Serif',
#  'Goudy Stout',
#  'Dubai',
#  'Poor Richard',
#  'Mistral',
#  'Bookshelf Symbol 7',
#  'Dubai',
#  'Trebuchet MS',
#  'HYGothic-Extra',
#  'Calisto MT',
#  'Ebrima',
#  'Microsoft Tai Le',
#  'Segoe Script',
#  'Courier New',
#  'Matura MT Script Capitals',
#  'Candara',
#  'Segoe UI',
#  'Copperplate Gothic Light',
#  'Eras Bold ITC',
#  'Georgia',
#  'Bodoni MT',
#  'Haan Wing2',
#  'Courier New',
#  'Bodoni MT',
#  'Corbel',
#  'Yu Gothic',
#  'Gill Sans MT',
#  'Lucida Sans',
#  'Curlz MT',
#  'Rockwell Condensed',
#  'Gill Sans MT',
#  'Harrington',
#  'Century Schoolbook',
#  'Berlin Sans FB',
#  'Myanmar Text',
#  'MT Extra',
#  'Microsoft PhagsPa',
#  'Lucida Sans Typewriter',
#  'MingLiU-ExtB',
#  'Constantia',
#  'Informal Roman',
#  'Segoe UI',
#  'Franklin Gothic Demi Cond',
#  'Palatino Linotype',
#  'Arial',
#  'Comic Sans MS',
#  'Arial',
#  'HCR Batang ExtB',
#  'Arial',
#  'HYGothic-Medium',
#  'Franklin Gothic Medium',
#  'Candara',
#  'Elephant',
#  'High Tower Text',
#  'Gill Sans MT Ext Condensed Bold',
#  'Microsoft New Tai Lue',
#  'Britannic Bold',
#  'Gabriola',
#  'Palatino Linotype',
#  'Niagara Engraved',
#  'Candara',
#  'Niagara Solid',
#  'French Script MT',
#  'Segoe UI Emoji',
#  'Franklin Gothic Book',
#  'Palatino Linotype',
#  'Felix Titling',
#  'Corbel',
#  'Gigi',
#  'Calisto MT',
#  'Verdana',
#  'LG PC',
#  'Eras Demi ITC',
#  'Segoe UI',
#  'Corbel',
#  'Segoe UI',
#  'Wingdings 3',
#  'Consolas',
#  'MV Boli',
#  'Segoe UI',
#  'Berlin Sans FB',
#  'Franklin Gothic Book',
#  'Playbill',
#  'Tahoma',
#  'Lucida Handwriting',
#  'Wingdings 2',
#  'Pyunji R',
#  'Constantia',
#  'Lucida Sans',
#  'Hancom MalangMalang',
#  'Lucida Fax',
#  'Century Gothic',
#  'Arial',
#  'HYPost-Medium',
#  'Yu Gothic',
#  'Book Antiqua',
#  'Kristen ITC',
#  'Times New Roman',
#  'Rockwell',
#  'Courier New',
#  'Californian FB',
#  'Segoe UI',
#  'Mongolian Baiti',
#  'Trebuchet MS',
#  'Copperplate Gothic Bold',
#  'Lucida Bright',
#  'Gill Sans Ultra Bold',
#  'Dubai',
#  'Tw Cen MT Condensed',
#  'Script MT Bold',
#  'Rockwell',
#  'Stencil',
#  'Rage Italic',
#  'Lucida Sans',
#  'Eras Light ITC',
#  'Bodoni MT',
#  'HYPMokGak-Bold',
#  'Arial',
#  'Calisto MT',
#  'Californian FB',
#  'Goudy Old Style',
#  'Tw Cen MT Condensed Extra Bold',
#  'Corbel',
#  'Bradley Hand ITC',
#  'Sitka',
#  'Constantia',
#  'Blackadder ITC',
#  'SimSun',
#  'Eras Medium ITC',
#  'Hancom Hoonminjeongeum_V',
#  'Palatino Linotype',
#  'Perpetua',
#  'HCR Batang',
#  'OCR A Extended',
#  'Calibri',
#  'Lucida Sans Typewriter',
#  'HCR Batang',
#  'Gadugi',
#  'Bookman Old Style',
#  'Franklin Gothic Demi',
#  'Microsoft PhagsPa',
#  'Microsoft Yi Baiti',
#  'Book Antiqua',
#  'Microsoft YaHei',
#  'Lucida Bright',
#  'Myanmar Text',
#  'Century',
#  'Nirmala UI',
#  'Century Schoolbook',
#  'MS Gothic',
#  'Tempus Sans ITC',
#  'Snap ITC',
#  'Verdana',
#  'Hancom Hoonminjeongeum_H',
#  'Berlin Sans FB Demi',
#  'Gadugi',
#  'Bodoni MT',
#  'Segoe MDL2 Assets',
#  'LG Smart UI',
#  'Segoe UI Variable',
#  'Bernard MT Condensed',
#  'Segoe Script',
#  'Calibri',
#  'Microsoft YaHei',
#  'Century Gothic',
#  'SimSun-ExtB',
#  'Cambria',
#  'Franklin Gothic Heavy',
#  'Rockwell',
#  'Juice ITC',
#  'Trebuchet MS',
#  'HYMyeongJo-Extra',
#  'Brush Script MT',
#  'Courier New',
#  'Bahnschrift',
#  'Lucida Fax',
#  'Maiandra GD',
#  'Segoe Print',
#  'High Tower Text',
#  'Tw Cen MT',
#  'Showcard Gothic',
#  'Headline R',
#  'Microsoft Himalaya',
#  'Agency FB',
#  'Malgun Gothic',
#  'Yu Gothic',
#  'Gulim',
#  'Elephant',
#  'Gloucester MT Extra Condensed',
#  'Malgun Gothic',
#  'Garamond',
#  'Perpetua',
#  'Webdings',
#  'Candara',
#  'Bell MT',
#  'Candara',
#  'MoeumT R',
#  'Lucida Sans',
#  'Arial',
#  'Yet R',
#  'LG Smart UI',
#  'Sitka',
#  'Book Antiqua',
#  'Perpetua Titling MT',
#  'Microsoft JhengHei',
#  'Forte',
#  'HoloLens MDL2 Assets',
#  'Broadway',
#  'Georgia',
#  'Kunstler Script',
#  'Arial',
#  'Monotype Corsiva',
#  'Han Santteut Dotum',
#  'Arial',
#  'Onyx',
#  'Tw Cen MT',
#  'Perpetua',
#  'Arial',
#  'HCR Batang ExtB',
#  'Century Gothic',
#  'Bodoni MT',
#  'Gill Sans MT',
#  'Magneto',
#  'HYGraphic-Medium',
#  'Comic Sans MS',
#  'Verdana',
#  'Book Antiqua',
#  'Batang',
#  'Segoe UI',
#  'Lucida Sans Unicode',
#  'Han Santteut Dotum',
#  'Lucida Bright',
#  'Times New Roman',
#  'Rockwell',
#  'Corbel',
#  'Consolas',
#  'LG Smart UI',
#  'Calisto MT']

# %%
plt.plot(x,y)
plt.title('꺾은 선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은 선 그래프')

# %%
plt.plot([-1,0,1],[-5,-1,2])

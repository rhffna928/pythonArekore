# %%
import PublicDataReader as pdr

print(pdr.__version__)
# Out:
# 1.1.0

# %%
svckey = "7EinowTIkEm3%2FDZaOqNJzsXT%2FkSpnrgeS%2F%2BZvubKAoTo0C2p54sohXEleJVpze9E79nsJZ8FaA9dC2St%2Fn4Ofg%3D%3D"

ts = pdr.Transportation(svckey, debug=True)

# %%
sigunguName = "분당구"
code = pdr.code_bdong()
code.loc[(code['시군구명'].str.contains(sigunguName, na=False)) | (code['읍면동명'].isna())]
# Out:
# 출처: 행정기관(행정동) 및 관할구역(법정동) 변경내역(2024.8.1. 시행)
#      시도코드  시도명  시군구코드     시군구명       법정동코드  읍면동명 동리명      생성일자 말소일자
# 5253   41  경기도  41135  성남시 분당구  4113500000            19910916
# 5254   41  경기도  41135  성남시 분당구  4113510100   분당동      19910916
# 5255   41  경기도  41135  성남시 분당구  4113510200   수내동      19930527
# 5256   41  경기도  41135  성남시 분당구  4113510300   정자동      19950307
# 5257   41  경기도  41135  성남시 분당구  4113510400    율동      19930115
# 5258   41  경기도  41135  성남시 분당구  4113510500   서현동      19920604
# 5259   41  경기도  41135  성남시 분당구  4113510600   이매동      19910916
# 5260   41  경기도  41135  성남시 분당구  4113510700   야탑동      19930527
# 5261   41  경기도  41135  성남시 분당구  4113510800   판교동      19910916
# 5262   41  경기도  41135  성남시 분당구  4113510900   삼평동      19930115
# 5263   41  경기도  41135  성남시 분당구  4113511000   백현동      19930115
# 5264   41  경기도  41135  성남시 분당구  4113511100   금곡동      19910916
# 5265   41  경기도  41135  성남시 분당구  4113511200   궁내동      19910916
# ...

# %%
# Out:
# [ERROR] <built-in function any> 참조 오류
# '<built-in function any> 참조 오류'

# %%
from PublicDataReader import TransactionPrice

service_Key = "7EinowTIkEm3%2FDZaOqNJzsXT%2FkSpnrgeS%2F%2BZvubKAoTo0C2p54sohXEleJVpze9E79nsJZ8FaA9dC2St%2Fn4Ofg%3D%3D"
api = TransactionPrice(service_Key)


# 기간 내 조회
df = api.get_data(
    property_type="아파트",
    trade_type="전월세",
    sigungu_code="11650",
    start_year_month="202201",
    end_year_month="202212",
)

df.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 8
#       4 api = TransactionPrice(service_Key)
#       7 # 기간 내 조회
# ----> 8 df = api.get_data(
#       9     property_type="아파트",
#      10     trade_type="전월세",
#      11     sigungu_code="11650",
#      12     start_year_month="202201",
#      13     end_year_month="202212",
#      14 )
#      16 df.tail()
#
# File c:\Python38\lib\site-packages\PublicDataReader\PublicDataPortal\molit.py:197, in TransactionPrice.get_data(self, property_type, trade_type, sigungu_code, year_month, start_year_month, end_year_month, verbose, **kwargs)
#     195 res = requests.get(url, params=params, verify=False)
#     196 res_json = xmltodict.parse(res.text)
# --> 197 if res_json['response']['header']['resultCode'] != '000':
#     198     error_message = res_json['response']['header']['resultMsg']
# ...

# %%
df
# Out:
# '<built-in function any> 참조 오류'

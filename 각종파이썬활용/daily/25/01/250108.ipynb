# %%
import requests
import pandas as pd


Key = "AE%2BAYfujB7mhHocWHzLgLXR0mP2f0xcsKcEPgjNKAJUn9C%2Fvv%2BzryEGqyZ07038iZvkJaHWSPxIgvNitxFdj2g%3D%3D"
url = 'http://apis.data.go.kr/B552061/lgStat/getRestLgStat?serviceKey='+Key
params ={
         'searchYearCd' : '2024',
         'siDo' : '1100',
         'guGun' : '1116',
         'type' : 'json',
         'numOfRows' : '100',
         'pageNo' : '1'
        }

response = requests.get(url, params=params)
#print(response.json())
data = response.json()

df = pd.DataFrame(data['items']['item'])
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests
import pandas as pd


Key = "AE%2BAYfujB7mhHocWHzLgLXR0mP2f0xcsKcEPgjNKAJUn9C%2Fvv%2BzryEGqyZ07038iZvkJaHWSPxIgvNitxFdj2g%3D%3D"
url = 'http://apis.data.go.kr/B552061/lgStat/getRestLgStat?serviceKey='+Key
params ={
         'searchYearCd' : '2023',
         'siDo' : '1700',
         'guGun' : '1723',
         'type' : 'json',
         'numOfRows' : '100',
         'pageNo' : '1'
        }

response = requests.get(url, params=params)
#print(response.json())
data = response.json()

df = pd.DataFrame(data['items']['item'])
df
# Out:
#    std_year sido_sgg_nm      acc_cl_nm acc_cnt acc_cnt_cmrt dth_dnv_cnt  \
# 0      2023    전라북도 익산시           전체사고     826         0.42          16
# 1      2023    전라북도 익산시          어린이사고      38         0.43           0
# 2      2023    전라북도 익산시          고령자사고     225         0.58          11
# 3      2023    전라북도 익산시          보행자사고     183         0.49           5
# 4      2023    전라북도 익산시          자전거사고      15         0.29           2
# 5      2023    전라북도 익산시           야간사고     283         0.39           6
# 6      2023    전라북도 익산시        어린이보행사고      12         0.46           0
# 7      2023    전라북도 익산시      스쿨존내어린이사고       4         0.82           0
# 8      2023    전라북도 익산시        고령운전자사고     188         0.47           5
# 9      2023    전라북도 익산시        고령보행자사고      62         0.57           5
# 10     2023    전라북도 익산시  개인형이동수단(PM)사고       9         0.38           0
# 11     2023    전라북도 익산시          뺑소니사고      27         0.40           0
# 12     2023    전라북도 익산시          무면허사고      28         0.54           1
#
#    dth_dnv_cnt_cmrt ftlt_rate injpsn_cnt injpsn_cnt_cmrt  ... cnt_027_03  \
# 0              0.63      1.94       1144            0.40  ...        131
# 1              0.00      0.00         44            0.40  ...        NaN
# 2              0.89      4.89        252            0.59  ...        NaN
# 3              0.56      2.73        184            0.49  ...        NaN
# 4              3.13     13.33         14            0.25  ...        NaN
# 5              0.52      2.12        392            0.39  ...        NaN
# 6              0.00      0.00         12            0.45  ...        NaN
# 7              0.00      0.00          4            0.76  ...        NaN
# 8              0.67      2.66        261            0.47  ...        NaN
# 9              0.91      8.06         57            0.54  ...        NaN
# 10             0.00      0.00          9            0.34  ...        NaN
# 11             0.00      0.00         34            0.37  ...        NaN
# 12             0.82      3.57         37            0.54  ...        NaN
#
#    cnt_027_04 cnt_027_05 cnt_027_06 cnt_027_07 cnt_027_99 cnt_014_01  \
# 0          38        437         20         40        113        181
# 1         NaN        NaN        NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN        NaN        NaN
# 4         NaN        NaN        NaN        NaN        NaN        NaN
# 5         NaN        NaN        NaN        NaN        NaN        NaN
# 6         NaN        NaN        NaN        NaN        NaN        NaN
# 7         NaN        NaN        NaN        NaN        NaN        NaN
# 8         NaN        NaN        NaN        NaN        NaN        NaN
# 9         NaN        NaN        NaN        NaN        NaN        NaN
# 10        NaN        NaN        NaN        NaN        NaN        NaN
# 11        NaN        NaN        NaN        NaN        NaN        NaN
# 12        NaN        NaN        NaN        NaN        NaN        NaN
#
#    cnt_014_02 cnt_014_03 cnt_014_04
# 0         629         16          0
# 1         NaN        NaN        NaN
# 2         NaN        NaN        NaN
# 3         NaN        NaN        NaN
# 4         NaN        NaN        NaN
# 5         NaN        NaN        NaN
# 6         NaN        NaN        NaN
# 7         NaN        NaN        NaN
# 8         NaN        NaN        NaN
# 9         NaN        NaN        NaN
# 10        NaN        NaN        NaN
# 11        NaN        NaN        NaN
# 12        NaN        NaN        NaN
#
# [13 rows x 27 columns]

# %%
import requests
import pandas as pd


Key = "AE%2BAYfujB7mhHocWHzLgLXR0mP2f0xcsKcEPgjNKAJUn9C%2Fvv%2BzryEGqyZ07038iZvkJaHWSPxIgvNitxFdj2g%3D%3D"
url = 'http://apis.data.go.kr/B552061/lgStat/getRestLgStat?serviceKey='+Key
params ={
         'searchYearCd' : '2024',
         'siDo' : '1100',
         'guGun' : '1116',
         'type' : 'json',
         'numOfRows' : '100',
         'pageNo' : '1'
        }

response = requests.get(url, params=params)
#print(response.json())
data = response.json()

df = pd.DataFrame(data['items']['item'])
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

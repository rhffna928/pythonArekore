# %%
import numpy as np
import pandas as pd

flight = pd.read_csv("./data/Clean_Dataset.csv", encoding='utf-8')

flight
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %%
flight2 = pd.read_csv("./data/Clean_Dataset.csv", index_col = 'stops', 
usecols=['stops', 'departure_time', 'arrival_time', 'destination_city'])
flight2
# Out:
#       departure_time   arrival_time destination_city
# stops
# zero         Evening          Night           Mumbai
# zero   Early_Morning        Morning           Mumbai
# zero   Early_Morning  Early_Morning           Mumbai
# zero         Morning      Afternoon           Mumbai
# zero         Morning        Morning           Mumbai
# ...              ...            ...              ...
# one          Morning        Evening        Hyderabad
# one        Afternoon          Night        Hyderabad
# one    Early_Morning          Night        Hyderabad
# one    Early_Morning        Evening        Hyderabad
# one          Morning        Evening        Hyderabad
#
# [300153 rows x 3 columns]

# %%
pd.crosstab(index = flight.source_city, columns= flight.arrival_time)
# Out:
# arrival_time  Afternoon  Early_Morning  Evening  Late_Night  Morning  Night
# source_city
# Bangalore          6992           3154    14493        2673    10411  14338
# Chennai            5152           1606    10830        1999     7106  12007
# Delhi              8007           5262    14630        2143    13007  18294
# Hyderabad          4816           1581    10539        2092     8854  12924
# Kolkata            5941           2156    11304        2414     9595  14937
# Mumbai             7231           1658    16527        2680    13762  19038

# %%
flight.shape
flight.columns
flight.info()
flight.describe()
flight.dtypes
flight.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB
# ...

# %%
flight[['departure_time']]
flight[['airline','departure_time','source_city']]
# Out:
#          airline departure_time source_city
# 0       SpiceJet        Evening       Delhi
# 1       SpiceJet  Early_Morning       Delhi
# 2        AirAsia  Early_Morning       Delhi
# 3        Vistara        Morning       Delhi
# 4        Vistara        Morning       Delhi
# ...          ...            ...         ...
# 300148   Vistara        Morning     Chennai
# 300149   Vistara      Afternoon     Chennai
# 300150   Vistara  Early_Morning     Chennai
# 300151   Vistara  Early_Morning     Chennai
# 300152   Vistara        Morning     Chennai
#
# [300153 rows x 3 columns]

# %%
flight[10:21]


flight.index = np.arange(100,300253)
flight.loc[[102,202,302]]
flight.iloc[[2,102,202]]

flight.loc[[102,202,302],['airline','flight','source_city','price']]

flight.iloc[[2,102,202],[1,2,3,11]]
# Out:
#      airline  flight source_city  price
# 102  AirAsia  I5-764       Delhi   5956
# 202  Vistara  UK-819       Delhi  18923
# 302  Vistara  UK-879       Delhi  13673

# %%
#데이터프레임에서는 
# & = and
# | = or
# ~ = not

flight_extract = flight[(flight['price']>12000)& (flight['airline'] == 'Air_India')]
flight_extract.head()
# Out:
#      Unnamed: 0    airline  flight source_city departure_time stops  \
# 140          40  Air_India  AI-504       Delhi          Night   one
# 141          41  Air_India  AI-502       Delhi      Afternoon   one
# 142          42  Air_India  AI-506       Delhi        Morning   one
# 143          43  Air_India  AI-803       Delhi  Early_Morning   one
# 144          44  Air_India  AI-479       Delhi          Night   one
#
#     arrival_time destination_city    class  duration  days_left  price
# 140      Morning           Mumbai  Economy     11.00          1  12150
# 141      Morning           Mumbai  Economy     19.08          1  12150
# 142      Morning           Mumbai  Economy     22.83          1  12150
# 143      Morning           Mumbai  Economy     26.42          1  12150
# 144    Afternoon           Mumbai  Economy     17.75          1  12215

# %%
price_tag = flight['price'] > 12000
airline_tag = flight['airline'] == 'Air_India'
flight_extract2 = flight[price_tag & airline_tag].head()
flight_extract2
# Out:
#      Unnamed: 0    airline  flight source_city departure_time stops  \
# 140          40  Air_India  AI-504       Delhi          Night   one
# 141          41  Air_India  AI-502       Delhi      Afternoon   one
# 142          42  Air_India  AI-506       Delhi        Morning   one
# 143          43  Air_India  AI-803       Delhi  Early_Morning   one
# 144          44  Air_India  AI-479       Delhi          Night   one
#
#     arrival_time destination_city    class  duration  days_left  price
# 140      Morning           Mumbai  Economy     11.00          1  12150
# 141      Morning           Mumbai  Economy     19.08          1  12150
# 142      Morning           Mumbai  Economy     22.83          1  12150
# 143      Morning           Mumbai  Economy     26.42          1  12150
# 144    Afternoon           Mumbai  Economy     17.75          1  12215

# %% [markdown]
# ### 데이터 추가하기
#
# ###### loc : 삽입될 열의 위치
# ###### column : 삽입될 열의 이름
# ###### value : 삽입될 열의 값
# ###### allow_duplicates :  중복 열의 삽일을 허용하는지 여부(기본값은 False)

# %%
flight.insert(10,'duration2', flight['duration']*10)
flight.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 flight.insert(10,'duration2', flight['duration']*10)
#       2 flight.head()
#
# File c:\Python38\lib\site-packages\pandas\core\frame.py:4772, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4766     raise ValueError(
#    4767         "Cannot specify 'allow_duplicates=True' when "
#    4768         "'self.flags.allows_duplicate_labels' is False."
#    4769     )
#    4770 if not allow_duplicates and column in self.columns:
#    4771     # Should this be a different kind of error??
# -> 4772     raise ValueError(f"cannot insert {column}, already exists")
#    4773 if not isinstance(loc, int):
#    4774     raise TypeError("loc must be int")
#
# ValueError: cannot insert duration2, already exists

# %%
flight.head()
# Out:
#      Unnamed: 0   airline   flight source_city departure_time stops  \
# 100           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 101           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 102           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 103           3   Vistara   UK-995       Delhi        Morning  zero
# 104           4   Vistara   UK-963       Delhi        Morning  zero
#
#       arrival_time destination_city    class  duration  duration2  days_left  \
# 100          Night           Mumbai  Economy      2.17       21.7          1
# 101        Morning           Mumbai  Economy      2.33       23.3          1
# 102  Early_Morning           Mumbai  Economy      2.17       21.7          1
# 103      Afternoon           Mumbai  Economy      2.25       22.5          1
# 104        Morning           Mumbai  Economy      2.33       23.3          1
#
#      price
# 100   5953
# 101   5953
# 102   5956
# 103   5955
# 104   5955

# %%
flight.drop('price',axis=1)
flight.drop(index=1000, axis=0)
flight.drop('price',axis=1, inplace=True)

# %%
flight = flight.rename(columns={'airline' : "airline_name", "source_city": "departure_city"})
flight.head()
# Out:
#      Unnamed: 0 airline_name   flight departure_city departure_time stops  \
# 100           0     SpiceJet  SG-8709          Delhi        Evening  zero
# 101           1     SpiceJet  SG-8157          Delhi  Early_Morning  zero
# 102           2      AirAsia   I5-764          Delhi  Early_Morning  zero
# 103           3      Vistara   UK-995          Delhi        Morning  zero
# 104           4      Vistara   UK-963          Delhi        Morning  zero
#
#       arrival_time destination_city    class  duration  duration2  days_left
# 100          Night           Mumbai  Economy      2.17       21.7          1
# 101        Morning           Mumbai  Economy      2.33       23.3          1
# 102  Early_Morning           Mumbai  Economy      2.17       21.7          1
# 103      Afternoon           Mumbai  Economy      2.25       22.5          1
# 104        Morning           Mumbai  Economy      2.33       23.3          1

# %%
flight = flight.sort_values(by="Unnamed: 0", ascending=False)
flight.head()
flight = flight.sort_values(by="Unnamed: 0", ascending=True)
flight.head()
# Out:
#      Unnamed: 0 airline_name   flight departure_city departure_time stops  \
# 100           0     SpiceJet  SG-8709          Delhi        Evening  zero
# 101           1     SpiceJet  SG-8157          Delhi  Early_Morning  zero
# 102           2      AirAsia   I5-764          Delhi  Early_Morning  zero
# 103           3      Vistara   UK-995          Delhi        Morning  zero
# 104           4      Vistara   UK-963          Delhi        Morning  zero
#
#       arrival_time destination_city    class  duration  duration2  days_left
# 100          Night           Mumbai  Economy      2.17       21.7          1
# 101        Morning           Mumbai  Economy      2.33       23.3          1
# 102  Early_Morning           Mumbai  Economy      2.17       21.7          1
# 103      Afternoon           Mumbai  Economy      2.25       22.5          1
# 104        Morning           Mumbai  Economy      2.33       23.3          1

# %%
mul_airline_group = flight.groupby(['airline_name','arrival_time'])
mul_airline_group.count()
# Out:
#                             Unnamed: 0  flight  departure_city  \
# airline_name arrival_time
# AirAsia      Afternoon            2052    2052            2052
#              Early_Morning        1407    1407            1407
#              Evening              2762    2762            2762
#              Late_Night           3491    3491            3491
#              Morning              2909    2909            2909
#              Night                3477    3477            3477
# Air_India    Afternoon           11576   11576           11576
#              Early_Morning        3405    3405            3405
#              Evening             18748   18748           18748
#              Late_Night           2090    2090            2090
#              Morning             20521   20521           20521
#              Night               24552   24552           24552
# GO_FIRST     Afternoon            3373    3373            3373
# ...

# %%
import numpy as np
import pandas as pd

flight = pd.read_csv("./data/Clean_Dataset.csv", encoding='utf-8')

flight.groupby(['airline','arrival_time']).count().loc[[('AirAsia','Evening')]]
# Out:
#                       Unnamed: 0  flight  source_city  departure_time  stops  \
# airline arrival_time
# AirAsia Evening             2762    2762         2762            2762   2762
#
#                       destination_city  class  duration  days_left  price
# airline arrival_time
# AirAsia Evening                   2762   2762      2762       2762   2762

# %%
flight.set_index(['airline','arrival_time'])
flight.set_index(['airline','arrival_time']).groupby(level=[0]).count()
# Out:
#            Unnamed: 0  flight  source_city  departure_time   stops  \
# airline
# AirAsia         16098   16098        16098           16098   16098
# Air_India       80892   80892        80892           80892   80892
# GO_FIRST        23173   23173        23173           23173   23173
# Indigo          43120   43120        43120           43120   43120
# SpiceJet         9011    9011         9011            9011    9011
# Vistara        127859  127859       127859          127859  127859
#
#            destination_city   class  duration  days_left   price
# airline
# AirAsia               16098   16098     16098      16098   16098
# Air_India             80892   80892     80892      80892   80892
# GO_FIRST              23173   23173     23173      23173   23173
# Indigo                43120   43120     43120      43120   43120
# SpiceJet               9011    9011      9011       9011    9011
# Vistara              127859  127859    127859     127859  127859

# %%
flight.set_index(['airline','arrival_time']).groupby(level=[0,1]).count()
# Out:
#                          Unnamed: 0  flight  source_city  departure_time  \
# airline   arrival_time
# AirAsia   Afternoon            2052    2052         2052            2052
#           Early_Morning        1407    1407         1407            1407
#           Evening              2762    2762         2762            2762
#           Late_Night           3491    3491         3491            3491
#           Morning              2909    2909         2909            2909
#           Night                3477    3477         3477            3477
# Air_India Afternoon           11576   11576        11576           11576
#           Early_Morning        3405    3405         3405            3405
#           Evening             18748   18748        18748           18748
#           Late_Night           2090    2090         2090            2090
#           Morning             20521   20521        20521           20521
# ...

# %%
flight.set_index(["airline",'arrival_time']).groupby(level=[0,1]).count().aggregate([np.mean, np.max])
# Out:
#         Unnamed: 0        flight   source_city  departure_time         stops  \
# mean   8337.583333   8337.583333   8337.583333     8337.583333   8337.583333
# amax  40693.000000  40693.000000  40693.000000    40693.000000  40693.000000
#
#       destination_city         class      duration     days_left         price
# mean       8337.583333   8337.583333   8337.583333   8337.583333   8337.583333
# amax      40693.000000  40693.000000  40693.000000  40693.000000  40693.000000
